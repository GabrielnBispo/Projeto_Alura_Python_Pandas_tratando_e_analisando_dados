# %% [markdown]
# # Relatório de Analise III

# %% [markdown]
# ## Imóveis Residenciais

# %%
import pandas as pd

# %%
dados= pd.read_csv('dados/aluguel.csv', sep = ';')

# %%
dados.head(10)
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
# 5              Apartamento     Vista Alegre        3      1       0    70
# 6              Apartamento         Cachambi        2      0       0    50
# 7       Casa de Condomínio  Barra da Tijuca        5      4       5   750
# 8       Casa de Condomínio            Ramos        2      2       0    65
# 9  Conjunto Comercial/Sala           Centro        0      3       0   695
#
#      Valor  Condominio    IPTU
# 0   1700.0       500.0    60.0
# 1   7000.0         NaN     NaN
# 2   5200.0      4020.0  1111.0
# ...

# %%
tipo_de_dados = dados['Tipo'].drop_duplicates()

# %%
tipo_de_dados
# Out:
# 0                          Quitinete
# 1                               Casa
# 2            Conjunto Comercial/Sala
# 3                        Apartamento
# 7                 Casa de Condomínio
# 16                    Prédio Inteiro
# 17                              Flat
# 29                        Loja/Salão
# 80           Galpão/Depósito/Armazém
# 83                    Casa Comercial
# 117                     Casa de Vila
# 159                   Terreno Padrão
# 207                      Box/Garagem
# 347                             Loft
# 589      Loja Shopping/ Ct Comercial
# 2157                         Chácara
# 3354           Loteamento/Condomínio
# 4379                           Sítio
# 4721                   Pousada/Chalé
# 6983                          Studio
# 9687                           Hotel
# 23614                      Indústria
# Name: Tipo, dtype: object

# %%
list(tipo_de_dados )
# Out:
# ['Quitinete',
#  'Casa',
#  'Conjunto Comercial/Sala',
#  'Apartamento',
#  'Casa de Condomínio',
#  'Prédio Inteiro',
#  'Flat',
#  'Loja/Salão',
#  'Galpão/Depósito/Armazém',
#  'Casa Comercial',
#  'Casa de Vila',
#  'Terreno Padrão',
#  'Box/Garagem',
#  'Loft',
#  'Loja Shopping/ Ct Comercial',
#  'Chácara',
#  'Loteamento/Condomínio',
#  'Sítio',
#  'Pousada/Chalé',
#  'Studio',
#  'Hotel',
#  'Indústria']

# %%
residencial = ['Quitinete',
 'Casa',
 'Apartamento',
 'Casa de Condomínio',
 'Casa de Vila',]

# %%
selecao= dados['Tipo'].isin (residencial)

# %%
selecao
# Out:
# 0         True
# 1         True
# 2        False
# 3         True
# 4         True
#          ...
# 32955     True
# 32956     True
# 32957     True
# 32958     True
# 32959    False
# Name: Tipo, Length: 32960, dtype: bool

# %%
dados_residencial= dados[selecao]

# %%
dados_residencial
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 3      Apartamento                Centro        1      0       0    15
# 4      Apartamento          Higienópolis        1      0       0    48
# 5      Apartamento          Vista Alegre        3      1       0    70
# ...            ...                   ...      ...    ...     ...   ...
# 32953  Apartamento                 Méier        2      0       0    70
# 32955    Quitinete                Centro        0      0       0    27
# 32956  Apartamento           Jacarepaguá        3      1       2    78
# 32957  Apartamento  São Francisco Xavier        2      1       0    48
# 32958  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU
# 0      1700.0       500.0  60.0
# 1      7000.0         NaN   NaN
# ...

# %%
list(dados_residencial['Tipo'].drop_duplicates())
# Out:
# ['Quitinete', 'Casa', 'Apartamento', 'Casa de Condomínio', 'Casa de Vila']

# %%
dados.shape[0]
# Out:
# 32960

# %%
dados_residencial.shape[0]
# Out:
# 22580

# %%
dados_residencial.index= range(dados_residencial.shape[0])

# %%
dados_residencial
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 2      Apartamento                Centro        1      0       0    15
# 3      Apartamento          Higienópolis        1      0       0    48
# 4      Apartamento          Vista Alegre        3      1       0    70
# ...            ...                   ...      ...    ...     ...   ...
# 22575  Apartamento                 Méier        2      0       0    70
# 22576    Quitinete                Centro        0      0       0    27
# 22577  Apartamento           Jacarepaguá        3      1       2    78
# 22578  Apartamento  São Francisco Xavier        2      1       0    48
# 22579  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU
# 0      1700.0       500.0  60.0
# 1      7000.0         NaN   NaN
# ...

# %% [markdown]
# ## FREESTYLE

# %%
dados
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 0                    Quitinete            Copacabana        1      0       0
# 1                         Casa       Jardim Botânico        2      0       1
# 2      Conjunto Comercial/Sala       Barra da Tijuca        0      4       0
# 3                  Apartamento                Centro        1      0       0
# 4                  Apartamento          Higienópolis        1      0       0
# ...                        ...                   ...      ...    ...     ...
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
#        Area   Valor  Condominio    IPTU
# ...

# %%
tipo_de_dados2 = dados['Tipo']. drop_duplicates()
tipo_de_dados2
# Out:
# 0                          Quitinete
# 1                               Casa
# 2            Conjunto Comercial/Sala
# 3                        Apartamento
# 7                 Casa de Condomínio
# 16                    Prédio Inteiro
# 17                              Flat
# 29                        Loja/Salão
# 80           Galpão/Depósito/Armazém
# 83                    Casa Comercial
# 117                     Casa de Vila
# 159                   Terreno Padrão
# 207                      Box/Garagem
# 347                             Loft
# 589      Loja Shopping/ Ct Comercial
# 2157                         Chácara
# 3354           Loteamento/Condomínio
# 4379                           Sítio
# 4721                   Pousada/Chalé
# 6983                          Studio
# 9687                           Hotel
# 23614                      Indústria
# Name: Tipo, dtype: object

# %%
list (tipo_de_dados2)
# Out:
# ['Quitinete',
#  'Casa',
#  'Conjunto Comercial/Sala',
#  'Apartamento',
#  'Casa de Condomínio',
#  'Prédio Inteiro',
#  'Flat',
#  'Loja/Salão',
#  'Galpão/Depósito/Armazém',
#  'Casa Comercial',
#  'Casa de Vila',
#  'Terreno Padrão',
#  'Box/Garagem',
#  'Loft',
#  'Loja Shopping/ Ct Comercial',
#  'Chácara',
#  'Loteamento/Condomínio',
#  'Sítio',
#  'Pousada/Chalé',
#  'Studio',
#  'Hotel',
#  'Indústria']

# %%
outros= ['Conjunto Comercial/Sala','Prédio Inteiro',
 'Flat',
 'Loja/Salão',
 'Galpão/Depósito/Armazém',
 'Casa Comercial','Terreno Padrão',
 'Box/Garagem',
 'Loft',
 'Loja Shopping/ Ct Comercial',
 'Chácara',
 'Loteamento/Condomínio',
 'Sítio',
 'Pousada/Chalé',
 'Studio',
 'Hotel',
 'Indústria']

# %%
selecao2= dados['Tipo']. isin (outros)
selecao2
# Out:
# 0        False
# 1        False
# 2         True
# 3        False
# 4        False
#          ...
# 32955    False
# 32956    False
# 32957    False
# 32958    False
# 32959     True
# Name: Tipo, Length: 32960, dtype: bool

# %%
dados_sem_ser_residencial = dados[selecao2 ]
dados_sem_ser_residencial
# Out:
#                           Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 2      Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 9      Conjunto Comercial/Sala           Centro        0      3       0   695
# 16              Prédio Inteiro         Botafogo        0      0       0   536
# 17                        Flat         Botafogo        3      1       1    80
# 25                        Flat           Leblon        1      0       0    56
# ...                        ...              ...      ...    ...     ...   ...
# 32942  Conjunto Comercial/Sala  Barra da Tijuca        0      1       0    55
# 32946  Conjunto Comercial/Sala           Centro        0      0       0   140
# 32948  Conjunto Comercial/Sala           Centro        0      0       0    32
# 32954              Box/Garagem           Centro        0      0       0   755
# 32959  Conjunto Comercial/Sala           Centro        0      0       0   250
#
# ...

# %%
dados_sem_ser_residencial.shape[0]
# Out:
# 10380

# %%
(dados_sem_ser_residencial.shape[0]) + (dados_residencial.shape[0])
# Out:
# 32960

# %%
dados_sem_ser_residencial.index= range (dados_sem_ser_residencial.shape[0])
dados_sem_ser_residencial
# Out:
#                           Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0      Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 1      Conjunto Comercial/Sala           Centro        0      3       0   695
# 2               Prédio Inteiro         Botafogo        0      0       0   536
# 3                         Flat         Botafogo        3      1       1    80
# 4                         Flat           Leblon        1      0       0    56
# ...                        ...              ...      ...    ...     ...   ...
# 10375  Conjunto Comercial/Sala  Barra da Tijuca        0      1       0    55
# 10376  Conjunto Comercial/Sala           Centro        0      0       0   140
# 10377  Conjunto Comercial/Sala           Centro        0      0       0    32
# 10378              Box/Garagem           Centro        0      0       0   755
# 10379  Conjunto Comercial/Sala           Centro        0      0       0   250
#
# ...

# %% [markdown]
# ## Exportando a base de dados

# %%
dados_residencial.to_csv('dados/aluguel_residencial.csv' , sep = ';')

# %%
dados_residencial2 = pd.read_csv ('dados/aluguel_residencial.csv' , sep = ';')

# %%
dados_residencial2
# Out:
#        Unnamed: 0         Tipo                Bairro  Quartos  Vagas  Suites  \
# 0               0    Quitinete            Copacabana        1      0       0
# 1               1         Casa       Jardim Botânico        2      0       1
# 2               2  Apartamento                Centro        1      0       0
# 3               3  Apartamento          Higienópolis        1      0       0
# 4               4  Apartamento          Vista Alegre        3      1       0
# ...           ...          ...                   ...      ...    ...     ...
# 22575       22575  Apartamento                 Méier        2      0       0
# 22576       22576    Quitinete                Centro        0      0       0
# 22577       22577  Apartamento           Jacarepaguá        3      1       2
# 22578       22578  Apartamento  São Francisco Xavier        2      1       0
# 22579       22579  Apartamento                Leblon        2      0       0
#
#        Area   Valor  Condominio  IPTU
# ...

# %% [markdown]
# ## Removendo o índice da exportação

# %%
dados_residencial.to_csv('dados/aluguel_residencial.csv' , sep = ';' , index= False)

# %%
dados_residencial2 = pd.read_csv ('dados/aluguel_residencial.csv' , sep = ';')

# %%
dados_residencial2
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 2      Apartamento                Centro        1      0       0    15
# 3      Apartamento          Higienópolis        1      0       0    48
# 4      Apartamento          Vista Alegre        3      1       0    70
# ...            ...                   ...      ...    ...     ...   ...
# 22575  Apartamento                 Méier        2      0       0    70
# 22576    Quitinete                Centro        0      0       0    27
# 22577  Apartamento           Jacarepaguá        3      1       2    78
# 22578  Apartamento  São Francisco Xavier        2      1       0    48
# 22579  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU
# 0      1700.0       500.0  60.0
# 1      7000.0         NaN   NaN
# ...
