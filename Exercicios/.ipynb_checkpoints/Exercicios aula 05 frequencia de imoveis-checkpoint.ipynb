# %% [markdown]
# # Exercicio

# %%
import pandas as pd

alunos = pd.DataFrame({'Nome': ['Ary', 'Cátia', 'Denis', 'Beto', 'Bruna', 'Dara', 'Carlos', 'Alice'], 
                        'Sexo': ['M', 'F', 'M', 'M', 'F', 'F', 'M', 'F'], 
                        'Idade': [15, 27, 56, 32, 42, 21, 19, 35], 
                        'Notas': [7.5, 2.5, 5.0, 10, 8.2, 7, 6, 5.6], 
                        'Aprovado': [True, False, False, True, True, True, False, False]}, 
                        columns = ['Nome', 'Idade', 'Sexo', 'Notas', 'Aprovado'])

# %%
alunos
# Out:
#      Nome  Idade Sexo  Notas  Aprovado
# 0     Ary     15    M    7.5      True
# 1   Cátia     27    F    2.5     False
# 2   Denis     56    M    5.0     False
# 3    Beto     32    M   10.0      True
# 4   Bruna     42    F    8.2      True
# 5    Dara     21    F    7.0      True
# 6  Carlos     19    M    6.0     False
# 7   Alice     35    F    5.6     False

# %% [markdown]
# ## Seleção Nivel 1 : dataframe com alunos aprovados

# %%
selecao = alunos['Aprovado'] == True
alunos[selecao]
aprovados = alunos[selecao]
aprovados.index= range(4)
aprovados
# Out:
#     Nome  Idade Sexo  Notas  Aprovado
# 0    Ary     15    M    7.5      True
# 1   Beto     32    M   10.0      True
# 2  Bruna     42    F    8.2      True
# 3   Dara     21    F    7.0      True

# %% [markdown]
# ## Seleção Nivel 2: dataframe somente com alunas aprovadas

# %%
alunos
# Out:
#      Nome  Idade Sexo  Notas  Aprovado
# 0     Ary     15    M    7.5      True
# 1   Cátia     27    F    2.5     False
# 2   Denis     56    M    5.0     False
# 3    Beto     32    M   10.0      True
# 4   Bruna     42    F    8.2      True
# 5    Dara     21    F    7.0      True
# 6  Carlos     19    M    6.0     False
# 7   Alice     35    F    5.6     False

# %%
selecao = (alunos['Aprovado'] == True) & (alunos['Sexo'] == 'F')
aprovadas = alunos[selecao]
aprovadas.index = range(2)
aprovadas
# Out:
#     Nome  Idade Sexo  Notas  Aprovado
# 0  Bruna     42    F    8.2      True
# 1   Dara     21    F    7.0      True

# %% [markdown]
# ## Seleção Nivel 3: Crie apenas uma visualização dos alunos com idade entre 10 e 20 anos ou com idade maior ou igual a 40 anos.

# %%
alunos
# Out:
#      Nome  Idade Sexo  Notas  Aprovado
# 0     Ary     15    M    7.5      True
# 1   Cátia     27    F    2.5     False
# 2   Denis     56    M    5.0     False
# 3    Beto     32    M   10.0      True
# 4   Bruna     42    F    8.2      True
# 5    Dara     21    F    7.0      True
# 6  Carlos     19    M    6.0     False
# 7   Alice     35    F    5.6     False

# %%
selecao = ((alunos['Idade'] >=10) & (alunos['Idade'] <=20)) | (alunos['Idade'] >=40) 

informacao = alunos[selecao]
informacao.index = range(4)
informacao
# Out:
#      Nome  Idade Sexo  Notas  Aprovado
# 0     Ary     15    M    7.5      True
# 1   Denis     56    M    5.0     False
# 2   Bruna     42    F    8.2      True
# 3  Carlos     19    M    6.0     False

# %% [markdown]
# ## Crie um DataFrame somente com os alunos reprovados e mantenha neste DataFrame apenas as colunas Nome, Sexo e Idade, nesta ordem.

# %%
alunos
# Out:
#      Nome  Idade Sexo  Notas  Aprovado
# 0     Ary     15    M    7.5      True
# 1   Cátia     27    F    2.5     False
# 2   Denis     56    M    5.0     False
# 3    Beto     32    M   10.0      True
# 4   Bruna     42    F    8.2      True
# 5    Dara     21    F    7.0      True
# 6  Carlos     19    M    6.0     False
# 7   Alice     35    F    5.6     False

# %%
selecao = alunos['Aprovado'] == False
reprovados = alunos[['Nome', 'Sexo', 'Idade']][selecao]
reprovados
# Out:
#      Nome Sexo  Idade
# 1   Cátia    F     27
# 2   Denis    M     56
# 6  Carlos    M     19
# 7   Alice    F     35

# %% [markdown]
# ## Crie uma visualização com os três alunos mais novos

# %%
alunos.sort_values(by = ['Idade'], inplace = True)
alunos.iloc[:3]
# Out:
#      Nome  Idade Sexo  Notas  Aprovado
# 0     Ary     15    M    7.5      True
# 6  Carlos     19    M    6.0     False
# 5    Dara     21    F    7.0      True

# %% [markdown]
# ## Estudar sobre sortvalues de novo
